# %%
number=input("숫자를 입력하세요: ")
number = int(number)

if number > 0:
  raise NotImplementedError("ArithmeticError: 양수는 허용되지 않습니다. 입력된 숫자: {}".format(number))
else:
  raise NotImplementedError("ArithmeticError: 음수는 허용되지 않습니다. 입력된 숫자: {}".format(number))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipython-input-846237082.py in <cell line: 0>()
#       3
#       4 if number > 0:
# ----> 5   raise NotImplementedError("ArithmeticError: 양수는 허용되지 않습니다. 입력된 숫자: {}".format(number))
#       6 else:
#       7   raise NotImplementedError("ArithmeticError: 음수는 허용되지 않습니다. 입력된 숫자: {}".format(number))
#
# NotImplementedError: ArithmeticError: 양수는 허용되지 않습니다. 입력된 숫자: 11
