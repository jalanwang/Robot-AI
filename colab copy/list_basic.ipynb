# %%
list_a=[1,2,3,4,5]
list_a[-1]
# Out:
# 5

# %%
list_b=[[1,2,3],[4,5,6],[7,8,9]]
list_b[1][2]
# Out:
# 6

# %%
list_b[1]
# Out:
# [4, 5, 6]

# %%
len(list_a),len(list_b)
# Out:
# (5, 3)

# %%
list_c=[[1,2,3,4,5],[1,2,3,4]]

# %%
list_c[0][4], list_c[1][3]
# Out:
# (5, 4)

# %%
len(list_c[0]), len(list_c[1])
# Out:
# (5, 4)

# %%
list_a=[1,2,3,4,5]
list_a.append(6)
list_a.append(7)
list_a
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
list_a.insert(0,0)
list_a
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
list_a.remove(0)
list_a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3139892828.py in <cell line: 0>()
# ----> 1 list_a.remove(0)
#       2 list_a
#
# ValueError: list.remove(x): x not in list

# %%
list_a.remove(1)
list_a
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
list_a.insert(0,0)
list_a
# Out:
# [0, 0, 0, 2, 3, 4, 5, 6, 7]

# %%
list_a.remove(0)
list_a
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
list_a.insert(0,1)
list_a
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
list_b=[7,8]
list_a.extend(list_b)
list_a
# Out:
# [1, 2, 3, 4, 5, 6, 7, 7, 8]

# %%
del list_a[0]
list_a
# Out:
# [2, 3, 4, 5, 6, 7, 7, 8]

# %%
del list_a[0:2]
list_a
# Out:
# [4, 5, 6, 7, 7, 8]

# %%
list_a.pop()
list_a
# Out:
# [4, 5, 6, 7, 7]

# %%
list_a.pop(0)
# Out:
# 4

# %%
list_a.clear()

# %%
list_a
# Out:
# []

# %%
list_a=[1,2,3,4,5]
3 in list_a
# Out:
# True

# %%
3 not in list_a
# Out:
# False

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in list_a:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for character in "hello":
  print('-',character)
# Out:
# - h
# - e
# - l
# - l
# - o
