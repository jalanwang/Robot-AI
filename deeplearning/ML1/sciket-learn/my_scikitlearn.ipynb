# %% [markdown]
# ## 기대수명 데이터 둘러보기(케글에서 가져왔음)

# %%
import pandas as pd


file = './life_expectancy.csv'
life = pd.read_csv(file)
print(life.head(3))
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
#
#    Thinness 1-19 years  Thinness 5-9 years  Income composition of resources  \
# 0                 17.2                17.3                            0.479
# 1                 17.5                17.5                            0.476
# 2                 17.7                17.7                            0.470
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
#
# [3 rows x 22 columns]

# %%
print(life.describe())
# Out:
#               Year  Life expectancy  Adult mortality  Infant deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  Percentage expenditure  Hepatitis B        Measles  \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#                BMI  Under-five deaths        Polio  Total expenditure  \
# count  2904.000000        2938.000000  2919.000000         2712.00000
# mean     38.321247          42.035739    82.550188            5.93819
# std      20.044034         160.445548    23.428046            2.49832
# min       1.000000           0.000000     3.000000            0.37000
# 25%      19.300000           0.000000    78.000000            4.26000
# 50%      43.500000           4.000000    93.000000            5.75500
# 75%      56.200000          28.000000    97.000000            7.49250
# max      87.300000        2500.000000    99.000000           17.60000
#
#         Diphtheria     HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#        Thinness 1-19 years  Thinness 5-9 years  \
# count          2904.000000         2904.000000
# mean              4.839704            4.870317
# std               4.420195            4.508882
# min               0.100000            0.100000
# 25%               1.600000            1.500000
# 50%               3.300000            3.300000
# 75%               7.200000            7.200000
# max              27.700000           28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %%
print(life.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult mortality',
#        'Infant deaths', 'Alcohol', 'Percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'Under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'Thinness 1-19 years',
#        'Thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
life.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
# 3   67.0               8.52        67.0       0.1  669.959000   3696958.0
# 4   68.0               7.87        68.0       0.1   63.537231   2978599.0
#
#    Thinness 1-19 years  Thinness 5-9 years  Income composition of resources  \
# 0                 17.2                17.3                            0.479
# 1                 17.5                17.5                            0.476
# 2                 17.7                17.7                            0.470
# 3                 17.9                18.0                            0.463
# 4                 18.2                18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %%
print(life.head(3))
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
#
#    Thinness 1-19 years  Thinness 5-9 years  Income composition of resources  \
# 0                 17.2                17.3                            0.479
# 1                 17.5                17.5                            0.476
# 2                 17.7                17.7                            0.470
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
#
# [3 rows x 22 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시본 라이브러리의 크기를 지정
sns.set(rc={'figure.figsize':(22,20)})
# 상관행렬을 나타내어보자. 이때 수치 데이터에 대한 상관계수를 구하도록 하자
correlation_matrix = life.corr(numeric_only=True).round(2)
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
life['Life expectancy']
# Out:
# 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
#         ...
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: Life expectancy, Length: 2938, dtype: float64

# %%
print("기대수명과의 상관계수")
print(life.corr(numeric_only=True).round(3)['Life expectancy'])
# Out:
# 기대수명과의 상관계수
# Year                               0.170
# Life expectancy                    1.000
# Adult mortality                   -0.696
# Infant deaths                     -0.197
# Alcohol                            0.405
# Percentage expenditure             0.382
# Hepatitis B                        0.257
# Measles                           -0.158
# BMI                                0.568
# Under-five deaths                 -0.223
# Polio                              0.466
# Total expenditure                  0.218
# Diphtheria                         0.479
# HIV/AIDS                          -0.557
# GDP                                0.461
# Population                        -0.022
# Thinness 1-19 years               -0.477
# Thinness 5-9 years                -0.472
# Income composition of resources    0.725
# Schooling                          0.752
# Name: Life expectancy, dtype: float64

# %%
import numpy as np

# 'Life expectancy'와 다른 속성들의 소수점 둘째 자리 상관계수를 구함
c = life.corr(numeric_only=True).round(2)['Life expectancy']
c = np.abs(c)       # 상관계수의 절대값을 취한다
print(c.sort_values(ascending=False)[1:8]) # 상위 7개 값을 출력하자
#자기 자신을 제외했다.

#그래프로 보는 법은 나중에 설명한다.
# Out:
# Schooling                          0.73
# Income composition of resources    0.72
# Adult mortality                    0.70
# HIV/AIDS                           0.59
# BMI                                0.54
# Thinness 5-9 years                 0.46
# Thinness 1-19 years                0.46
# Name: Life expectancy, dtype: float64

# %%
print('Life expectancy와 상관도 순서로 정렬 후 하위 5개 값')
print(c.sort_values(ascending=False)[-6:-1]) # 하위 5개 슬라이싱
# Out:
# Life expectancy와 상관도 순서로 정렬 후 하위 5개 값
# Under-five deaths    0.22
# Total expenditure    0.22
# Infant deaths        0.20
# Year                 0.17
# Measles              0.16
# Name: Life expectancy, dtype: float64

# %% [markdown]
# ## 쌍 그래프로 특성 분석하기

# %%
sns.pairplot(life[['Life expectancy', 'Schooling',\
                  'Income composition of resources',\
                  'Adult mortality', 'BMI', 'HIV/AIDS']])
plt.show()

# %% [markdown]
# ## 빈 값 갯수 찾기

# %%
life.isna().sum().sort_values(ascending=False)
# Out:
# Population                         652
# Hepatitis B                        553
# GDP                                448
# Total expenditure                  226
# Alcohol                            194
# Income composition of resources    167
# Schooling                          163
# Thinness 1-19 years                 34
# Thinness 5-9 years                  34
# BMI                                 34
# Diphtheria                          19
# Polio                               19
# Life expectancy                     10
# Adult mortality                     10
# Infant deaths                        0
# Status                               0
# Country                              0
# Year                                 0
# Under-five deaths                    0
# Measles                              0
# Percentage expenditure               0
# HIV/AIDS                             0
# dtype: int64

# %% [markdown]
# **특정 값에 대한 미싱 갯수 찾기**

# %%
main_features = ['Schooling', 'Income composition of resources', 'Adult mortality', 'BMI', 'HIV/AIDS']
life[main_features].isna().sum()
# Out:
# Schooling                          163
# Income composition of resources    167
# Adult mortality                     10
# BMI                                 34
# HIV/AIDS                             0
# dtype: int64

# %% [markdown]
# ### 결측값 제거

# %%
life.dropna(inplace=True) # 결측값 제거

X = life[main_features]
y = life['Life expectancy']
print(X.shape, y.shape ) # 결측값 제거 후 X, y 차원크기
# Out:
# (1649, 5) (1649,)

# %%
print(X.shape)
# Out:
# (1649, 5)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=84, test_size = 0.2)
print(X_train.shape)
print(y_train.shape)
regr = LinearRegression()
regr.fit(X_train, y_train)

y_predict=regr.predict(X_test).round(1)
print(y_predict)
print('선형 회귀 모델의 점수=', regr.score(X_test, y_test))
# Out:
# (1319, 5)
# (1319,)
# [51.6 68.2 67.9 69.6 74.6 78.7 76.4 75.1 75.9 72.1 55.8 65.2 76.8 61.3
#  64.5 71.2 54.5 77.8 55.5 72.6 70.6 71.1 72.  76.2 67.8 68.4 73.8 50.9
#  68.3 67.5 64.2 69.5 76.8 78.1 78.3 64.7 73.9 68.1 75.9 55.6 64.1 74.3
#  75.5 71.2 71.7 76.3 81.6 79.9 72.9 77.  79.2 70.7 61.1 44.4 63.9 59.
#  69.7 81.5 75.1 68.8 70.6 67.2 75.8 73.6 73.5 64.6 60.7 81.1 69.4 59.3
#  74.6 73.2 71.3 63.  79.4 56.  73.1 84.4 73.4 76.6 71.2 47.  60.2 74.2
#  76.2 71.3 65.2 64.5 77.5 65.  74.4 42.1 69.6 79.5 60.9 56.3 61.  72.5
#  81.7 61.8 71.5 59.7 69.7 80.  67.7 60.4 59.1 72.3 70.2 82.4 69.  73.9
#  57.6 73.7 70.1 60.2 71.5 80.2 71.1 65.6 73.2 78.2 65.8 75.  67.9 64.3
#  72.3 72.9 76.5 76.3 39.7 73.5 65.8 53.6 69.1 68.8 61.2 58.8 76.9 80.9
#  67.1 72.7 78.4 84.1 77.7 63.3 79.9 72.3 60.1 60.8 62.2 77.3 80.  71.3
#  77.2 70.4 77.7 72.9 73.7 71.6 57.8 42.3 68.8 73.  80.6 77.1 72.6 70.
#  70.4 64.  61.5 63.4 80.1 72.7 78.7 60.8 61.4 78.8 76.3 74.9 68.4 70.4
#  77.8 71.9 59.9 79.4 64.4 61.4 63.1 64.2 67.6 57.7 62.1 76.9 67.1 71.1
#  73.3 46.2 66.2 63.7 59.7 72.2 68.6 75.  63.3 56.  69.5 58.1 65.8 78.1
#  80.8 72.4 60.6 72.1 68.4 69.3 71.7 56.1 71.3 64.2 64.  79.  66.8 63.1
#  63.8 75.2 64.2 68.2 70.  49.1 69.1 71.6 71.3 69.  77.5 70.3 71.1 74.4
#  67.1 70.2 75.9 78.6 70.5 57.3 75.8 59.8 58.4 71.7 56.2 58.6 68.3 71.
#  63.2 72.2 69.9 67.4 71.2 60.3 62.  69.1 71.3 76.1 79.1 69.2 80.2 66.3
#  68.  53.9 71.7 68.5 77.6 67.8 60.8 49.6 67.7 73.3 69.6 69.8 43.7 77.9
#  62.6 69.8 63.8 71.6 67.1 73.5 55.8 83.2 59.1 71.8 55.4 72.3 66.  70.6
#  72.  58.6 65.6 78.5 68.4 50.2 73.9 70.6 78.1 71.6 70.5 68.6 79.1 62.3
#  76.5 69.5 61.8 78.  61.2 71.7 67.1 76.9 75.8 56.3 68.5 77.9 56.7 75.
#  49.6 68.2 74.4 72.8 76.  72.  72.3 75.6]
# 선형 회귀 모델의 점수= 0.8188281290307104

# %% [markdown]
# ## 선형회귀 그래프의 시각화 방법

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
y_test_predict = regr.predict(X_test)
plt.scatter(y_test, y_test_predict)
plt.plot(y_test, y_test, color='r', linewidth=3)

# %% [markdown]
# ## 훈련 데이터, 검증 데이터, 그리고 특성

# %%
import pandas as pd


file = './life_expectancy.csv'
life = pd.read_csv(file)

life.dropna(inplace=True) # 결측값 제거

# 'Country', 'Year', 'Status', 'Life expectancy'를 제외한 속성 사용
X = life[['Year','Adult mortality','Infant deaths', 'Alcohol',
          'Percentage expenditure','Hepatitis B', 'Measles',
          'BMI', 'Under-five deaths', 'Polio',
          'Total expenditure','Diphtheria', 'HIV/AIDS', 'GDP',
          'Population','Thinness 1-19 years','Thinness 5-9 years',
          'Income composition of resources', 'Schooling']]
y = life['Life expectancy']
print(X.shape)
# Out:
# (1649, 19)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=84, test_size = 0.2)
regr = LinearRegression()
regr.fit(X_train, y_train)
print('선형회귀 모델의 점수 =', regr.score(X_test, y_test))
# Out:
# 선형회귀 모델의 점수 = 0.8340254726170686

# %% [markdown]
# ## 상관도를 시각화하여 중요 특성을 분석

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file = './life_expectancy.csv'

life = pd.read_csv(file)
life.dropna(inplace=True) # 결측값 제거
# 'Country', 'Status', 'Life expectancy'를 제외한 속성 사용
X = life[['Year','Adult mortality','Infant deaths', 'Alcohol',
         'Percentage expenditure','Hepatitis B', 'Measles',
         'BMI', 'Under-five deaths', 'Polio',
         'Total expenditure','Diphtheria', 'HIV/AIDS', 'GDP',
         'Population','Thinness 1-19 years','Thinness 5-9 years',
         'Income composition of resources', 'Schooling']]

# 'Life expectancy'와 다른 속성들의 상관계수를 구함
c = life.corr(numeric_only=True)['Life expectancy']
c = np.abs(c)       # 상관계수의 절대값을 취한다
c.sort_values(ascending=True, inplace=True)
c = c[:-1] # 제일 뒤에 있는 Life expectancy는 제거

plt.figure(figsize=(7,7))
plt.barh(c.index, c.values)
plt.title('Correlation Coef with Life expectancy')
plt.xlabel('Features')
plt.ylabel('Correlation Coef')
# Out:
# Text(0, 0.5, 'Correlation Coef')

# %% [markdown]
# ## 데이터의 분포가 직선이 아니라면? 다항 회귀 모델을 사용한다.

# %%
import numpy as np
import matplotlib.pyplot as plt

m = 100    # 생성할 데이터의 개수
# 평균값이 0이고 -4에서 4사이에 분포하는 랜덤 값 X
np.random.seed(84)   # 매번 동일한 결과를 얻기 위하여 시드를 84로 부여하자
X = 8 * np.random.rand(m, 1) - 4 #100행 1열을 의미한다.

# x^2항의 계수가 0.5, x항의 계수가 2, 상수항의 계수가 1
y = 0.5 * X ** 2 + 2 * X + 1 + np.random.randn(m, 1)

plt.figure(figsize=(6,4))
plt.plot(X, y, "b^")

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# 8.7 절의 데이터 X
m = 100    # 생성할 데이터의 갯수
# 평균값이 0이고 -4에서 4사이에 분포하는 랜덤 값 X
X = 8 * np.random.rand(m, 1) - 4
# x^2항의 계수가 0.5, x항의 계수가 2, 상수항의 계수가 1
y = 0.5 * X ** 2 + 2 * X + 1 + np.random.randn(m, 1)

poly_features = PolynomialFeatures(degree = 2,\
                                   include_bias = False)
X_poly = poly_features.fit_transform(X)
regr = LinearRegression()
regr.fit(X_poly, y)
print('다항 회귀 모델의 점수 =', regr.score(X_poly, y))
print('다항 회귀 모델의 계수 =', regr.coef_, '절편 =', regr.intercept_)
# Out:
# 다항 회귀 모델의 점수 = 0.9670434060024024
# 다항 회귀 모델의 계수 = [[2.01366932 0.48503522]] 절편 = [1.2914879]

# %%
# -4에서 4사이의 데이터를 생성하자.
domain = np.linspace(-4, 4, 50).reshape(-1, 1)
# domain 데이터에 2차 다항 특성을 추가한 domain_2를 만들자
domain_2 = poly_features.fit_transform(domain)
domain_2
# Out:
# array([[-4.00000000e+00,  1.60000000e+01],
#        [-3.83673469e+00,  1.47205331e+01],
#        [-3.67346939e+00,  1.34943773e+01],
#        [-3.51020408e+00,  1.23215327e+01],
#        [-3.34693878e+00,  1.12019992e+01],
#        [-3.18367347e+00,  1.01357768e+01],
#        [-3.02040816e+00,  9.12286547e+00],
#        [-2.85714286e+00,  8.16326531e+00],
#        [-2.69387755e+00,  7.25697626e+00],
#        [-2.53061224e+00,  6.40399833e+00],
#        [-2.36734694e+00,  5.60433153e+00],
#        [-2.20408163e+00,  4.85797584e+00],
#        [-2.04081633e+00,  4.16493128e+00],
#        [-1.87755102e+00,  3.52519783e+00],
#        [-1.71428571e+00,  2.93877551e+00],
#        [-1.55102041e+00,  2.40566431e+00],
#        [-1.38775510e+00,  1.92586422e+00],
#        [-1.22448980e+00,  1.49937526e+00],
#        [-1.06122449e+00,  1.12619742e+00],
#        [-8.97959184e-01,  8.06330696e-01],
#        [-7.34693878e-01,  5.39775094e-01],
#        [-5.71428571e-01,  3.26530612e-01],
#        [-4.08163265e-01,  1.66597251e-01],
#        [-2.44897959e-01,  5.99750104e-02],
#        [-8.16326531e-02,  6.66389005e-03],
#        [ 8.16326531e-02,  6.66389005e-03],
#        [ 2.44897959e-01,  5.99750104e-02],
#        [ 4.08163265e-01,  1.66597251e-01],
#        [ 5.71428571e-01,  3.26530612e-01],
#        [ 7.34693878e-01,  5.39775094e-01],
#        [ 8.97959184e-01,  8.06330696e-01],
#        [ 1.06122449e+00,  1.12619742e+00],
#        [ 1.22448980e+00,  1.49937526e+00],
#        [ 1.38775510e+00,  1.92586422e+00],
#        [ 1.55102041e+00,  2.40566431e+00],
#        [ 1.71428571e+00,  2.93877551e+00],
#        [ 1.87755102e+00,  3.52519783e+00],
#        [ 2.04081633e+00,  4.16493128e+00],
#        [ 2.20408163e+00,  4.85797584e+00],
#        [ 2.36734694e+00,  5.60433153e+00],
#        [ 2.53061224e+00,  6.40399833e+00],
#        [ 2.69387755e+00,  7.25697626e+00],
#        [ 2.85714286e+00,  8.16326531e+00],
#        [ 3.02040816e+00,  9.12286547e+00],
#        [ 3.18367347e+00,  1.01357768e+01],
#        [ 3.34693878e+00,  1.12019992e+01],
#        [ 3.51020408e+00,  1.23215327e+01],
#        [ 3.67346939e+00,  1.34943773e+01],
#        [ 3.83673469e+00,  1.47205331e+01],
#        [ 4.00000000e+00,  1.60000000e+01]])

# %%
plt.figure(figsize=(6,4))
y_predict = regr.predict(domain_2)
plt.scatter(X, y)
plt.plot(domain, y_predict, color='r', linewidth=4)

# %% [markdown]
# <h1>3차 폴리노미얼</h1>
#
#
# x 값의 범위가 -4에서 4  사이의 값이고,
# 다음의 3차 방정식을 만족하느 분포를 가지는 y 데이터를 생성하여 그림과 같이 시각화하여라
# 데이터의 개수는 모두 100개이며 y값에 정규 분표를 따르는 난수가 들어가도록 하여라.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

np.random.seed(84)  # 재현성을 위한 시드 설정
X = np.linspace(-4, 4, 100).reshape(-1, 1)  # 2차원 배열로 생성

noise = np.random.normal(0, 1, size=X.shape)

y = 0.5 * X ** 3 + 0.5 * X**2 + X + 3 + noise

plt.scatter(X, y)

# %%
poly_features = PolynomialFeatures(degree = 3,\
                                   include_bias = False)
X_poly = poly_features.fit_transform(X)
regr = LinearRegression()
regr.fit(X_poly, y)
print('다항 회귀 모델의 점수 =', regr.score(X_poly, y))
print('다항 회귀 모델의 계수 =', regr.coef_, '절편 =', regr.intercept_)
# Out:
# 다항 회귀 모델의 점수 = 0.9946226420292454
# 다항 회귀 모델의 계수 = [[1.1049047  0.5013831  0.49432864]] 절편 = [2.75208071]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

m = 20      # 20개의 데이터를 생성하자
X = 8 * np.random.rand(m, 1) - 4
y = .5 * X ** 3 + .5 * X ** 2 + X + 3 + np.random.randn(m, 1)

# 20개의 데이터를 학습용 데이터, 테스트 데이터로 구분하자
X_train, X_test, y_train, y_test = train_test_split(X, y)

plt.figure(figsize=(6,5))
plt.xlim(-5, 5); plt.ylim(-28, 50) # x, y 범위를 제한함
plt.plot(X_train, y_train, "b^")   # 학습용 데이터를 그리자

# %%
# 다항 회귀 모델을 만들고 점수와 계수, 절편을 출력
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# 다항 특성이 20개가 되도록 하자
poly_features = PolynomialFeatures(degree = 20, include_bias = False)
X_poly = poly_features.fit_transform(X_train)
regr = LinearRegression()
regr.fit(X_poly, y_train)

print('다항 회귀 모델의 점수 =', regr.score(X_poly, y_train))
print('다항 회귀 모델의 계수 =', regr.coef_)
print('절편 =', regr.intercept_)
# Out:
# 다항 회귀 모델의 점수 = 0.9999999999680039
# 다항 회귀 모델의 계수 = [[-4.15641637e+00 -6.81878514e-01  3.37031825e+00 -2.15766255e-01
#    1.78673714e+00  8.78889176e-01  8.68293122e-01  1.08244503e+00
#    3.25206146e-01  5.73135350e-01 -1.83792242e-01 -5.38398536e-01
#   -3.55938648e-03  1.30233865e-01  6.71354968e-03 -1.43935035e-02
#   -7.26905297e-04  7.68741014e-04  2.32549686e-05 -1.62053729e-05]]
# 절편 = [0.94131529]

# %%
# 다항 회귀 곡선을 생성하는 기능
X_new = np.linspace(-4, 4, 100).reshape(100, 1)
X_new_poly = poly_features.transform(X_new)
y_new = regr.predict(X_new_poly)

plt.figure(figsize=(7,6))
plt.xlim(-5, 5); plt.ylim(-28, 50) # x, y 범위를 제한함

# 학습용 데이터와 다항 회귀 곡선을 그려보고 테스트 데이터도 그려보자
plt.plot(X_train, y_train, 'b^')
plt.scatter(X_test, y_test, c='red', s=200, alpha=0.4)
plt.plot(X_new, y_new, "r-", label="Prediction curve")
plt.legend()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# 20개의 데이터를 생성하자
m = 20
X = 8 * np.random.rand(m, 1) - 4
y = .5 * X ** 3 + .5 * X ** 2 + X + 3 + np.random.randn(m, 1)
# 20개의 데이터를 학습용 데이터, 테스트 데이터로 구분하자
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.5)
# 다항 특성이 20개가 되도록 하자
poly_features = PolynomialFeatures(degree = 1,\
                                  include_bias = False)
X_train_pl = poly_features.fit_transform(X_train)
X_test_pl = poly_features.fit_transform(X_test)

regr = LinearRegression()
regr.fit(X_train_pl, y_train)

print('훈련 데이터의 점수 =', regr.score(X_train_pl, y_train))
print('테스트 데이터의 점수 =', regr.score(X_test_pl, y_test))
# Out:
# 훈련 데이터의 점수 = 0.9306527426404161
# 테스트 데이터의 점수 = 0.8229333258467909

# %%
### 규제를 추가해 보자 ##
from sklearn.preprocessing import StandardScaler

ss = StandardScaler() # 규제가 있는 모델은 스케일러로 변환을 해야 함
ss.fit(X_train_pl)
train_scaled = ss.transform(X_train_pl)
test_scaled = ss.transform(X_test_pl)
### 릿지 회귀 ###
from sklearn.linear_model import Ridge
ridge = Ridge(alpha = 10)
ridge.fit(train_scaled, y_train)
print('훈련 데이터의 점수 =', ridge.score(train_scaled, y_train))
print('테스트 데이터의 점수 =', ridge.score(test_scaled, y_test))
# Out:
# 훈련 데이터의 점수 = 0.6979895569803118
# 테스트 데이터의 점수 = 0.6141428689333921

# %%
import matplotlib.pyplot as plt

train_scores = []
test_scores = []
alpha_values = [0.001, 0.01, 1, 10, 100, 1000]
for a in alpha_values:
  ridge = Ridge(alpha = a)
  ridge.fit(train_scaled, y_train)
  train_scores.append(ridge.score(train_scaled, y_train))
  test_scores.append(ridge.score(test_scaled, y_test))

plt.plot(np.log10(alpha_values), train_scores, 'r-', label='Train score')
plt.plot(np.log10(alpha_values), test_scores, 'b:', label='Test score')
plt.xlabel('Alpha value : 10^x scaled')
plt.ylabel('Ridge Regression')
plt.legend(loc="lower left")
