# %%
print("Hellow world")
# Out:
# Hellow world

# %%
a:list=[1,2,3,4,5]

# %%
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
b=(1,2,3,4,5)

# %%
type(b)
# Out:
# tuple

# %%
import numpy as np

# %%
np.array(a)
# Out:
# array([1, 2, 3, 4, 5])

# %%
c=[1,2,3.0]

# %%
np.array(c)
# Out:
# array([1., 2., 3.])

# %%
print(np.array(c))
# Out:
# [1. 2. 3.]

# %%
type(c)
# Out:
# list

# %%
np_c=np.array(c)

# %%
type(np_c)
# Out:
# numpy.ndarray

# %%
np_a=np.array(a)

# %%
type(np_a)
# Out:
# numpy.ndarray

# %%
a = np.array([1, 2, 3, 4], dtype = np.int32)
