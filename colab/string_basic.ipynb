# %%
a="    안녕하세요.    "
b=a.strip()
b
# Out:
# '안녕하세요.'

# %%
a="Hello World"
a.isalpha()
# Out:
# False

# %%
a.split(" ")
# Out:
# ['Hello', 'World']

# %%
test = (
  '동해물과 '
  '백두산이 '
  '마르고 닳도록 '
)

print(test)
# Out:
# 동해물과 백두산이 마르고 닳도록

# %%
test = (
  '동해물과 \n'
  '백두산이 \n'
  '마르고 닳도록'
)

print(test)
# Out:
# 동해물과
# 백두산이
# 마르고 닳도록

# %%
print("::".join(["1","2","3"  ]))
# Out:
# 1::2::3
