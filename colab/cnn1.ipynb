# %% [markdown]
# # vgg19에 대해서 공부한다

# %%
# tensorflow와 tf.keras를 임포트
import tensorflow as tf

# %%
class VGG19(tf.keras.models.Sequential):
  def __init__(self, input_shape):
    super(VGG19, self).__init__() # 상위 클래스 초기화 펑션 호출
    # block 1
    self.add(tf.keras.layers.Conv2D(64, (3,3), activation='relu',
                                    padding='same', input_shape=input_shape))
    self.add(tf.keras.layers.Conv2D(64, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.MaxPooling2D((2,2), strides=(2,2)))

    # block 2
    self.add(tf.keras.layers.Conv2D(128, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.Conv2D(128, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.MaxPooling2D((2,2), strides=(2,2)))

    # block 3
    self.add(tf.keras.layers.Conv2D(256, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.Conv2D(256, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.Conv2D(256, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.Conv2D(256, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.MaxPooling2D((2,2), strides=(2,2)))

    # block 4
    self.add(tf.keras.layers.Conv2D(512, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.Conv2D(512, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.Conv2D(512, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.Conv2D(512, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.MaxPooling2D((2,2), strides=(2,2)))

    # block 5
    self.add(tf.keras.layers.Conv2D(512, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.Conv2D(512, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.Conv2D(512, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.Conv2D(512, (3,3), activation='relu',
                                    padding='same'))
    self.add(tf.keras.layers.MaxPooling2D((2,2), strides=(2,2)))

    # DNN Full Connected
    self.add(tf.keras.layers.Flatten())
    self.add(tf.keras.layers.Dense(units=4096, activation='relu'))
    self.add(tf.keras.layers.Dense(units=4096, activation='relu'))
    self.add(tf.keras.layers.Dense(units=1000, activation='softmax'))

# 모델 선언
model=VGG19(input_shape=(224,224,3))

# Compile
optimizer=tf.keras.optimizers.Adam(learning_rate=0.003)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

## 뉴련 64, 커널 3,3 padding은 그림에 없어도 same을 넣는다.
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 112, 112, 128)  │       147,584 │
# ...
