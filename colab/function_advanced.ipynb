# %% [markdown]
# # 피보나치 수열

# %%
def fibonacci(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)

print(fibonacci(10))
print(fibonacci(20))
print(fibonacci(30))
print(fibonacci(40))
print(fibonacci(50))
# Out:
# 9227465

# %%
memo = { 1:1, 2:2
}

def fibonacci(n):
  if n in memo:
    return memo[n]

  else:
    output = fibonacci(n-1) + fibonacci(n-2)
    memo[n] = output
    return output


print(fibonacci(10))
print(fibonacci(20))
print(fibonacci(30))
print(fibonacci(40))
print(fibonacci(50))
# Out:
# 89
# 10946
# 1346269
# 165580141
# 20365011074

# %%
import time

def fibonacci(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)

start_time = time.time()
print(fibonacci(10))
end_time = time.time()
print(f"fibonacci(10) 실행 시간: {end_time - start_time:.6f}초")

start_time = time.time()
print(fibonacci(20))
end_time = time.time()
print(f"fibonacci(20) 실행 시간: {end_time - start_time:.6f}초")

start_time = time.time()
print(fibonacci(30))
end_time = time.time()
print(f"fibonacci(30) 실행 시간: {end_time - start_time:.6f}초")

start_time = time.time()
print(fibonacci(40))
end_time = time.time()
print(f"fibonacci(40) 실행 시간: {end_time - start_time:.6f}초")

start_time = time.time()
print(fibonacci(50))
end_time = time.time()
print(f"fibonacci(50) 실행 시간: {end_time - start_time:.6f}초")
# Out:
# 55
# fibonacci(10) 실행 시간: 0.000116초
# 6765
# fibonacci(20) 실행 시간: 0.002616초
# 832040
# fibonacci(30) 실행 시간: 0.193410초
# 102334155
# fibonacci(40) 실행 시간: 20.331308초
# 12586269025
# fibonacci(50) 실행 시간: 3142.982443초

# %%
import time

memo = { 1:1, 2:2
}

def fibonacci(n):
  if n in memo:
    return memo[n]

  else:
    output = fibonacci(n-1) + fibonacci(n-2)
    memo[n] = output
    return output


start_time = time.time()
print(fibonacci(10))
end_time = time.time()
print(f"fibonacci(10) 실행 시간: {end_time - start_time:.6f}초")

start_time = time.time()
print(fibonacci(20))
end_time = time.time()
print(f"fibonacci(20) 실행 시간: {end_time - start_time:.6f}초")

start_time = time.time()
print(fibonacci(30))
end_time = time.time()
print(f"fibonacci(30) 실행 시간: {end_time - start_time:.6f}초")

start_time = time.time()
print(fibonacci(40))
end_time = time.time()
print(f"fibonacci(40) 실행 시간: {end_time - start_time:.6f}초")

start_time = time.time()
print(fibonacci(50))
end_time = time.time()
print(f"fibonacci(50) 실행 시간: {end_time - start_time:.6f}초")
# Out:
# 89
# fibonacci(10) 실행 시간: 0.000167초
# 10946
# fibonacci(20) 실행 시간: 0.000030초
# 1346269
# fibonacci(30) 실행 시간: 0.000027초
# 165580141
# fibonacci(40) 실행 시간: 0.000026초
# 20365011074
# fibonacci(50) 실행 시간: 0.000027초

# %% [markdown]
# **리스트를 평탄화하는 재귀함수를 만드시오**

# %%
def flatten(data):
    result = []
    for item in data:
        if isinstance(item, list):
            result.extend(flatten(item))
        else:
            result.append(item)
    return result

data=[1,2,3, [4,5,6], "hello"]
print(flatten(data))
# Out:
# [1, 2, 3, 4, 5, 6, 'hello']

# %%
a=[1,2,3]
b=[4,5,6]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def flatten(data):
    result = []
    for item in data:
        if type(item) == list:
            result.extend(flatten(item))
        else:
            result.append(item)
    return result

data=[1,2,3, [4,5,6], "hello"]
print(flatten(data))
# Out:
# [1, 2, 3, 4, 5, 6, 'hello']

# %%
def flatten(data):
    result=[]
    for item in data:
        if type(item) == list:
            result = result+ flatten(item)
        else:
            result.append(item)
    return result

data=[1,2,3, [4,5,6], "hello"]

print(flatten(data))
# Out:
# [1, 2, 3, 4, 5, 6, 'hello']

# %%
a,b,c=1,2,3
d=(4,5,6)

a
# Out:
# 1

# %%
d
# Out:
# (4, 5, 6)

# %%
d.extend(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 d.extend(a)
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
c=a+d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 c=a+d
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
c=a
print(a), print(c)
# Out:
# 1
# 1
# (None, None)

# %%
def func_a():
    return(10)

def func_b():
    return(10,)

result_a = func_a()
result_b = func_b()

print(func_a())
print(func_b())
# Out:
# 10
# (10,)

# %%
def test():
    return(10,20)

print(test())
# Out:
# (10, 20)

# %%
def test():
    return (10,20)

print(test())
# Out:
# (10, 20)

# %%
def call_10_times(func):
    for i in range(10):
        func()

def func():
    print("안녕")

call_10_times(func)
# Out:
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕

# %%
def call_10_times(func):
    for i in range(10):
        func()

def print_hello():
    print("안녕")

call_10_times(print_hello())
# Out:
# 안녕
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 8
#       5 def print_hello():
#       6     print("안녕")
# ----> 8 call_10_times(print_hello())
#
# Cell In[25], line 3, in call_10_times(func)
#       1 def call_10_times(func):
#       2     for i in range(10):
# ----> 3         func()
#
# TypeError: 'NoneType' object is not callable

# %%
def my_power(list_a):
    for i in list_a:
        list_a[i]=i*i

list_a=[1,2,3]

my_power(list_a)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 7
#       3         list_a[i]=i*i
#       5 list_a=[1,2,3]
# ----> 7 my_power(list_a)
#
# Cell In[2], line 3, in my_power(list_a)
#       1 def my_power(list_a):
#       2     for i in list_a:
# ----> 3         list_a[i]=i*i
#
# IndexError: list assignment index out of range

# %%
def my_power(list_a):
    for i, value in enumerate(list_a):
        list_a[i]=value*value
    return list_a
list_a=[1,2,3]

print(my_power(list_a))
# Out:
# [1, 4, 9]

# %%
def my_power(list_a):
    for i, value in enumerate(list_a):
        list_a[i]=value*value
    return list_a
list_a=[1,2,3]

new_list=my_power(list_a)
print(list_a)
print(new_list)
# Out:
# [1, 4, 9]
# [1, 4, 9]

# %% [markdown]
# **원본 오염을 방지하려고 아랫처럼 짜면 에러**

# %%
def my_power(list_a):
    list_b=[]
    for i, value in enumerate(list_a):
        list_b[i]=value*value
    return list_b
list_a=[1,2,3]

print(my_power(list_a))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 8
#       5     return list_b
#       6 list_a=[1,2,3]
# ----> 8 print(my_power(list_a))
#
# Cell In[15], line 4, in my_power(list_a)
#       2 list_b=[]
#       3 for i, value in enumerate(list_a):
# ----> 4     list_b[i]=value*value
#       5 return list_b
#
# IndexError: list assignment index out of range

# %%
def my_power(list_a):
    list_b=[]
    for i, value in enumerate(list_a):
        list_b.append(value*value)
    return list_b
list_a=[1,2,3]

print(my_power(list_a))
print(list_a)
# Out:
# [1, 4, 9]
# [1, 2, 3]

# %%
def my_power(list_a):
    for i in range(len(list_a)):
        list_a[i]=list_a[i]*list_a[i]
    return list_a

list_a=[1,2,3]

new_list=my_power(list_a)

print(list_a)
print(new_list)
# Out:
# [1, 4, 9]
# [1, 4, 9]

# %%
#리스트컴프리핸션으로 구해보자
def my_power(list_a):
    return([i*i for i in list_a])

list_a=[1,2,3]

print(my_power(list_a))
# Out:
# [1, 4, 9]
