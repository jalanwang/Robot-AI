# %%
try:
    file = open("info.txt", 'w')

    file.close()

except Exception as e:
    print(e)

print('#파일이 제대로 댣혔는지 확인하기"')
print("file.closed:", file.closed)
# Out:
# #파일이 제대로 댣혔는지 확인하기"
# file.closed: True

# %% [markdown]
# **finally는 언제 사용해?**<p>
# <li>while과 같은 loop에서 breake가 걸려도 fianlly는 수행된다.
# <li>try에서 return을 만나도 finally는 수행된다.

# %% [markdown]
# **raise구문**

# %% [markdown]
# pass를 사용하면 나중에 구현여부를 모른다. 그래서 raise로 강제 에러를 만들어 낸다.

# %%
number = int(input('정수를 입력하시오'))

if number > 0:
    raise NotImplementedError
else:
    raise NotImplementedError
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 number = int(input('정수를 입력하시오'))
#       3 if number > 0:
# ----> 4     raise NotImplementedError
#       5 else:
#       6     raise NotImplementedError
#
# NotImplementedError:
